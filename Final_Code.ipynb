# %%
pip install pycld2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pycld2 in /usr/local/lib/python3.7/dist-packages (0.41)

# %%
import pycld2 as cld2
import pandas as pd

# %% [markdown]
# #Data Clean

# %%
df_trump = pd.read_csv('hashtag_donaldtrump.csv',lineterminator='\n')
df_biden = pd.read_csv('hashtag_joebiden.csv',lineterminator='\n')

# %%
df_trump.shape[0],df_biden.shape[0]

# %%
import pycld2 as cld2
def detect_lang(tweets):
    try:
        isReliable, textBytesFound, details = cld2.detect(tweets)
        return details[0][0]
    except:
        return "not found"

# %%
trump_eng=df_trump['tweet'].apply(detect_lang)
biden_eng=df_biden['tweet'].apply(detect_lang)

# %%
trump_eng.shape[0]
# Out:
# 970919

# %%
language_trump = [trump_eng[i] for i in range(len(trump_eng))]
language_biden = [biden_eng[i] for i in range(len(biden_eng))]
df_trump['language'] = language_trump
df_biden['language'] = language_biden

# %%
df_trump_eng = df_trump[df_trump['language'] == 'ENGLISH']
df_biden_eng = df_biden[df_biden['language'] == 'ENGLISH']

# %%
df_trump_eng_us = df_trump_eng[(df_trump_eng['country']=='United States of America')].reset_index().drop('index',axis=1)
df_biden_eng_us = df_biden_eng[(df_biden_eng['country']=='United States of America')].reset_index().drop('index',axis=1)
df_biden_eng_us.shape[0],df_trump_eng_us.shape[0]
# Out:
# (138367, 166328)

# %% [markdown]
# #Topic Modeling

# %%
#the module 'sys' allows istalling module from inside Jupyter
import sys

# !{sys.executable} -m pip install numpy
import numpy as np

# !{sys.executable} -m pip install pandas
import pandas as pd

#Natrual Language ToolKit (NLTK)
# !{sys.executable} -m pip install nltk
import nltk

# !{sys.executable} -m pip install sklearn
from sklearn import metrics
#from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import  CountVectorizer #bag-of-words vectorizer 
from sklearn.decomposition import LatentDirichletAllocation #package for LDA

# Plotting tools

from pprint import pprint
# !{sys.executable} -m pip install pyLDAvis #visualizing LDA
import pyLDAvis
import pyLDAvis.sklearn

import matplotlib.pyplot as plt
# %matplotlib inline

#define text normalization function
# %run ./Text_Normalization_Function.ipynb #defining text normalization function

#ignore warnings about future changes in functions as they take too much space
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Normalization Trump

# %%
# Trump normalization
df_trump_eng_us.tweet=normalize_corpus(df_trump_eng_us.tweet)
df_trump_eng_us.tweet.head()
# Out:
# 0    trump student use hear year ten year hear chin...
# 1          tie tie trump rally iowa http co jjaluumh5d
# 2    clady62 minute long time ago omarosa never rep...
# 3    deeviousdenise realdonaldtrump nypost wont man...
# 4    single effective remedy eradicate another roun...
# Name: tweet, dtype: object

# %% [markdown]
# ## Normalization Biden

# %%
# Biden normalization
df_biden_eng_us.tweet=normalize_corpus(df_biden_eng_us.tweet)
df_biden_eng_us.tweet.head()
# Out:
# 0    islandgirlprv bradbeauregardj meidastouch bide...
# 1    censorship hunterbiden biden bidenemails biden...
# 2    nypost censorship censored twitter manipulate ...
# 3    fbi allegedly obtain hunter biden computer dat...
# 4    comment democrat understand ruthless china htt...
# Name: tweet, dtype: object

# %%
#define the bag-of-words vectorizer:
bow_vectorizer_trump = CountVectorizer()
bow_vectorizer_biden = CountVectorizer()
#vectorize the normalized data:
trump=bow_vectorizer_trump.fit_transform(df_trump_eng_us.tweet)
biden=bow_vectorizer_biden.fit_transform(df_biden_eng_us.tweet)

# %% [markdown]
# ## LDA Trump

# %%
lda_trump=LatentDirichletAllocation(n_components=10, max_iter=150, ##change the number of topics and iteration here
                                           doc_topic_prior = 0.9,
                                           topic_word_prior = 0.1).fit(trump)

# %% [markdown]
# ## LDA Biden

# %%
lda_biden=LatentDirichletAllocation(n_components=10, max_iter=150, ##change the number of topics and iteration here
                                           doc_topic_prior = 0.9,
                                           topic_word_prior = 0.1).fit(biden)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))
        
def get_topic_words(vectorizer, lda_model, n_words):
    keywords = np.array(vectorizer.get_feature_names())
    topic_words = []
    for topic_weights in lda_model.components_:
        top_word_locs = (-topic_weights).argsort()[:n_words]
        topic_words.append(keywords.take(top_word_locs).tolist())
    return topic_words

# %% [markdown]
# ## Topic Modeling Trump

# %%
# Trump Topic
no_top_words = 30
display_topics(lda_trump, bow_vectorizer_trump.get_feature_names(), no_top_words)
# Out:
# Topic 0:
# trump covid19 covid via news new rally donald coronavirus live day case hold video pandemic watch https president youtube week politics death virus record penny whitehouse include since police number
# Topic 1:
# trump know think take good lie even debate give well last keep really debates2020 mean much talk never hear question start cant show person anything watch real na tonight thats
# Topic 2:
# president trump america gop american time us year country care white every great million tax world house pay blue first life votehimout usa could stand next remember history hope kill
# Topic 3:
# trump need campaign big fact use work medium twitter tweet believe everyone court may sure call claim put russia move fire post maybe fake story attack least face without hard
# Topic 4:
# biden trump election2020 election joebiden win bidenharris2020 joe electionday elections2020 poll lead electionresults2020 2020election politics fight kamalaharris call electionnight vote2020 biden2020 presidential victory candidate result want pa close party violence
# Topic 5:
# co http donaldtrump trump read stock bus iowa article color trumpiscompromised cold de common votebiden north box special trumpisapos free medical conference multiple winning trumpcovid19 omaha lockhimup 2020election treatment votebluedownballot
# Topic 6:
# trump realdonaldtrump like maga trump2020 right supporter let look potus way dont thing love im maga2020 happen guy speak long always best feel lot thank kag yes youre around trump2020landslide
# Topic 7:
# vote trump republican state lose democrat voter count stop ballot run fraud today florida pennsylvania day truth michigan wait texas voting arizona steal mail usa wisconsin sign senate share red
# Topic 8:
# trump people want support still many family leave bad help ever nothing end job another anyone racist must yet die office loser economy law corrupt play never something bring reason
# Topic 9:
# trump man cnn please foxnews black china money trumpmeltdown obama bidenharris god woman hate mask call fuck msnbc name old head little full sad guess wear lol wonder hand dumptrump

# %% [markdown]
# ## Topic Modeling Biden

# %%
# Biden Topic
display_topics(lda_biden, bow_vectorizer_biden.get_feature_names(), no_top_words)
# Out:
# Topic 0:
# like people america american year good country right need look love work im man life help much job care world great hope party feel hear put god thank ever speak
# Topic 1:
# trump biden trump2020 republican news voter cnn usa maga co black politics foxnews happen http read presidency donald fraud https breaking follow nbc endorse police ha tv nyc fox trump2020landslide
# Topic 2:
# obama biden campaign lie hunter family white hunterbiden bidens house run take corruption fact son office nothing never na another corrupt senate joebidens gon fbi email claim administration even crime
# Topic 3:
# co http biden election2020 bidenharris2020 vote biden2020 electionday elections2020 2020election vote2020 electionnight florida michigan texas wisconsin bidenharristosaveamerica trumpmeltdown pennsylvania votehimout electionresults2020 blacklivesmatter maga2020 counteveryvote bidenharrislandslide2020 2020elections bidenharris2020tosaveamerica votebidenharris2020 voteearly ohio
# Topic 4:
# biden democrat want us let show support medium talk twitter use story post check oh political sign economy hunterbiden hunterbidenemails share break fracking kill high law control die protect full
# Topic 5:
# biden joe know co http china plan big tax really question video guy yes must money bidens thats business pay word tweet youre answer true policy deal rt hey ukraine
# Topic 6:
# co http joebiden bidenharris debate donaldtrump watch debates2020 via tonight msnbc live voteblue blm youtube presidentialdebate2020 wtpblue child debatetonight debate2020 take resist dumptrump please great wtpsenate retweet demcast presidential click
# Topic 7:
# joebiden president kamalaharris time harris elect new today first bidenharis2020 next united election2020results speech woman history kamala state vice presidentelectjoe co joebiden2020 become congratulation presidentelect happy joebidenkamalaharris2020 abc http celebrate
# Topic 8:
# vote win biden election day call state count lead ballot poll stop georgia last every pa pennsylvania take need mail blue still night point nevada early presidential voting trump electionresults2020
# Topic 9:
# vote realdonaldtrump biden think give dont well lose thing covid19 keep supporter covid gop even believe many way change wait million candidate already bad potus everyone cant still start anyone

# %%
#prepare to display result in the Jupyter notebook
pyLDAvis.enable_notebook()

#run the visualization [mds is a function to use for visualizing the "distance" between topics]
pyLDAvis.sklearn.prepare(lda_trump, trump, bow_vectorizer_trump, mds='tsne')
# Out:
# PreparedData(topic_coordinates=               x          y  topics  cluster       Freq
# topic
# 5      32.420952   8.115230       1        1  10.950855
# 1       0.648955  71.707100       2        1  10.489350
# 3      71.019684   9.971006       3        1  10.385888
# 4       3.785981  33.185135       4        1  10.099764
# 2     -42.666500  -9.222070       5        1   9.982806
# 6      -3.621689 -43.526516       6        1   9.836496
# 8      -3.632402  -4.171708       7        1   9.787679
# 7     -36.584400  35.804413       8        1   9.524877
# 0      44.391380  50.615383       9        1   9.500456
# 9      40.235809 -31.591665      10        1   9.441828, topic_info=                   Term          Freq          Total Category  logprob  \
# 41204                co  92439.000000   92439.000000  Default  30.0000
# 80183              http  90890.000000   90890.000000  Default  29.0000
# 176825             vote  31889.000000   31889.000000  Default  28.0000
# 29907             biden  28907.000000   28907.000000  Default  27.0000
# 139777  realdonaldtrump  17777.000000   17777.000000  Default  26.0000
# ...                 ...           ...            ...      ...      ...
# 30036       bidenharris   2017.028162    2192.866429  Topic10  -4.8473
# 75814              hand    936.285224     982.098509  Topic10  -5.6148
# 164556            trump  25214.284244  167149.970877  Topic10  -2.3215
# 36431              call   1534.698024    4738.004470  Topic10  -5.1206
# 54191         dumptrump    927.034269    1071.365347  Topic10  -5.6247
#
#         loglift
# 41204   30.0000
# 80183   29.0000
# 176825  28.0000
# 29907   27.0000
# 139777  26.0000
# ...         ...
# 30036    2.2764
# 75814    2.3122
# 164556   0.4685
# 36431    1.2327
# 54191    2.2153
#
# [423 rows x 6 columns], token_table=        Topic      Freq          Term
# term
# 3682        1  0.113129  2020election
# 3682        4  0.886404  2020election
# 19951       1  0.997863        afford
# 20378       4  0.998264         ahead
# 21479       3  0.998723         allow
# ...       ...       ...           ...
# 189855      6  0.999737           yes
# 189900      7  0.999544           yet
# 191059      9  0.997950          york
# 191230      6  0.999571         youre
# 191314      9  0.999197       youtube
#
# [485 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 2, 4, 5, 3, 7, 9, 8, 1, 10])

# %%
#prepare to display result in the Jupyter notebook
pyLDAvis.enable_notebook()

#run the visualization [mds is a function to use for visualizing the "distance" between topics]
pyLDAvis.sklearn.prepare(lda_biden, biden, bow_vectorizer_biden, mds='tsne')
# Out:
# PreparedData(topic_coordinates=               x          y  topics  cluster       Freq
# topic
# 0      32.420952   8.115230       1        1  11.172740
# 9       0.648955  71.707100       2        1  10.784564
# 3      71.019684   9.971006       3        1  10.691039
# 8       3.785981  33.185135       4        1  10.546313
# 2     -42.666500  -9.222070       5        1  10.030477
# 6      -3.621689 -43.526516       6        1   9.912235
# 1      -3.632402  -4.171708       7        1   9.522192
# 7     -36.584400  35.804413       8        1   9.204417
# 5      44.391380  50.615383       9        1   9.101082
# 4      40.235809 -31.591665      10        1   9.034940, topic_info=                     Term          Freq         Total Category  logprob  \
# 76869            joebiden  61775.000000  61775.000000  Default  30.0000
# 67781                http  76624.000000  76624.000000  Default  29.0000
# 35293                  co  77885.000000  77885.000000  Default  28.0000
# 138580              trump  40527.000000  40527.000000  Default  27.0000
# 25141               biden  93239.000000  93239.000000  Default  26.0000
# ...                   ...           ...           ...      ...      ...
# 85280                left    698.211083    699.044794  Topic10  -5.6305
# 144031                 us   4639.172155   5234.998872  Topic10  -3.7368
# 25141               biden   9876.675739  93239.914535  Topic10  -2.9811
# 68039   hunterbidenemails    871.181136   1030.866725  Topic10  -5.4092
# 68025         hunterbiden    921.032964   2897.539718  Topic10  -5.3536
#
#         loglift
# 76869   30.0000
# 67781   29.0000
# 35293   28.0000
# 138580  27.0000
# 25141   26.0000
# ...         ...
# 85280    2.4029
# 144031   2.2832
# 25141    0.1591
# 68039    2.2358
# 68025    1.2579
#
# [423 rows x 6 columns], token_table=        Topic      Freq           Term
# term
# 3184        3  0.999571   2020election
# 3188        3  0.998875  2020elections
# 6577        8  0.998892           46th
# 15719       8  0.973537            abc
# 15719       9  0.026338            abc
# ...       ...       ...            ...
# 158308      1  0.999840           year
# 158417      9  0.999474            yes
# 158455      2  0.999077            yet
# 159598      9  0.999566          youre
# 159667      6  0.999267        youtube
#
# [457 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 10, 4, 9, 3, 7, 2, 8, 6, 5])

# %% [markdown]
# # Sentiment Analysis

# %%
#packages needed

#ignore warnings about future changes in functions as they take too much space
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

#the module 'sys' allows istalling module from inside Jupyter
import sys

# !{sys.executable} -m pip install numpy
import numpy as np 

# !{sys.executable} -m pip install pandas
import pandas as pd

#Natrual Language ToolKit (NLTK)
# !{sys.executable} -m pip install nltk
import nltk

#text normalization function
# %run ./Text_Normalization_Function.ipynb

#ignore warnings about future changes in functions as they take too much space
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: html.parser in /usr/local/lib/python3.7/dist-packages (0.2)
# Requirement already satisfied: ply in /usr/local/lib/python3.7/dist-packages (from html.parser) (3.11)
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pattern3 in /usr/local/lib/python3.7/dist-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from pattern3) (4.6.3)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.7/dist-packages (from pattern3) (6.0.10)
# Requirement already satisfied: docx in /usr/local/lib/python3.7/dist-packages (from pattern3) (0.2.4)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.7/dist-packages (from pattern3) (3.18.0)
# Requirement already satisfied: cherrypy in /usr/local/lib/python3.7/dist-packages (from pattern3) (18.8.0)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.7/dist-packages (from pattern3) (20221105)
# Requirement already satisfied: pdfminer3k in /usr/local/lib/python3.7/dist-packages (from pattern3) (1.3.4)
# Requirement already satisfied: jaraco.collections in /usr/local/lib/python3.7/dist-packages (from cherrypy->pattern3) (3.8.0)
# Requirement already satisfied: cheroot>=8.2.1 in /usr/local/lib/python3.7/dist-packages (from cherrypy->pattern3) (9.0.0)
# Requirement already satisfied: portend>=2.1.1 in /usr/local/lib/python3.7/dist-packages (from cherrypy->pattern3) (3.1.0)
# Requirement already satisfied: zc.lockfile in /usr/local/lib/python3.7/dist-packages (from cherrypy->pattern3) (2.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from cherrypy->pattern3) (9.0.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from cheroot>=8.2.1->cherrypy->pattern3) (1.15.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.7/dist-packages (from cheroot>=8.2.1->cherrypy->pattern3) (3.5.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from cheroot>=8.2.1->cherrypy->pattern3) (4.13.0)
# Requirement already satisfied: tempora>=1.8 in /usr/local/lib/python3.7/dist-packages (from portend>=2.1.1->cherrypy->pattern3) (5.1.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern3) (2022.6)
# Requirement already satisfied: Pillow>=2.0 in /usr/local/lib/python3.7/dist-packages (from docx->pattern3) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from docx->pattern3) (4.9.1)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.7/dist-packages (from feedparser->pattern3) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->cheroot>=8.2.1->cherrypy->pattern3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->cheroot>=8.2.1->cherrypy->pattern3) (3.10.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.7/dist-packages (from jaraco.collections->cherrypy->pattern3) (3.2.3)
# Requirement already satisfied: jaraco.text in /usr/local/lib/python3.7/dist-packages (from jaraco.collections->cherrypy->pattern3) (3.11.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (5.10.0)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/local/lib/python3.7/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (4.2.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (2.1.0)
# Requirement already satisfied: autocommand in /usr/local/lib/python3.7/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (2.2.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.7/dist-packages (from pdfminer.six->pattern3) (38.0.4)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from pdfminer.six->pattern3) (2.1.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=36.0.0->pdfminer.six->pattern3) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern3) (2.21)
# Requirement already satisfied: ply in /usr/local/lib/python3.7/dist-packages (from pdfminer3k->pattern3) (3.11)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from zc.lockfile->cherrypy->pattern3) (57.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.0.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.7.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.2.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.8.4)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (0.16.0)
# Requirement already satisfied: funcy in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (57.4.0)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (from pyLDAvis) (3.6.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.0->pyLDAvis) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyLDAvis) (3.1.0)
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  ['<', 'p', '>', 'The', 'circus', 'dog', 'in', 'a', 'plissé', 'skirt', 'jumped', 'over', 'Python', 'who', 'was', "n't", 'that', 'large', ',', 'just', '3', 'feet', 'long.', '<', '/p', '>']
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  <p>The circus dog in a plissé skirt jumped over Python who was not that large, just 3 feet long.</p>
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  [('<', 'a'), ('p', 'n'), ('>', 'v'), ('the', None), ('circus', 'n'), ('dog', 'n'), ('in', None), ('a', None), ('plissé', 'n'), ('skirt', 'n'), ('jumped', 'v'), ('over', None), ('python', 'n'), ('who', None), ('was', 'v'), ("n't", 'r'), ('that', None), ('large', 'a'), (',', None), ('just', 'r'), ('3', None), ('feet', 'n'), ('long.', 'a'), ('<', 'n'), ('/p', 'n'), ('>', 'n')]
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  < p > the circus dog in a plissé skirt jump over python who be n't that large , just 3 foot long. < /p >
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:    p   The circus dog in a plissé skirt jumped over Python who was n t that large   just 3 feet long     p
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  < p > The circus dog plissé skirt jumped Python n't large , 3 feet long. < /p >
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  p The circus dog in a plissé skirt jumped over Python who was n't that large just feet long. /p
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.
# Original:   <p>The circus dog in a plissé skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# Processed:  <p>The circus dog in a plisse skirt jumped over Python who wasn't that large, just 3 feet long.</p>
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
def analyze_sentiment_vader_lexicon(review, threshold = 0.1, verbose = False):
    scores = analyzer.polarity_scores(review)  
    binary_sentiment = 'positive' if scores['compound'] >= threshold else 'negative'
    if verbose:                             
        print('VADER Polarity (Binary):', binary_sentiment)
        print('VADER Score:', round(scores['compound'], 2))
    return binary_sentiment,scores['compound']

# %% [markdown]
# ## Trump

# %%
Trump_VADER_polarity_test = [analyze_sentiment_vader_lexicon(review, threshold=0.1) for review in df_trump_eng_us.tweet]
Trump_VADER_polarity_test_df = pd.DataFrame(Trump_VADER_polarity_test, columns = ['VADER Polarity','VADER Score'])
pd.DataFrame({"count":Trump_VADER_polarity_test_df['VADER Polarity'].value_counts(),"precentage":Trump_VADER_polarity_test_df['VADER Polarity'].value_counts(normalize=True)})
# Out:
#            count  precentage
# negative  106954    0.643031
# positive   59374    0.356969

# %%
df_trump_eng_us_polarity = pd.merge(df_trump_eng_us,Trump_VADER_polarity_test_df['VADER Polarity'],left_index=True, right_index=True)
df_trump_eng_us_polarity
# Out:
#                  created_at      tweet_id  \
# 0       2020-10-15 00:00:02  1.316529e+18
# 1       2020-10-15 00:00:08  1.316529e+18
# 2       2020-10-15 00:00:17  1.316529e+18
# 3       2020-10-15 00:00:18  1.316529e+18
# 4       2020-10-15 00:00:20  1.316529e+18
# ...                     ...           ...
# 166323  2020-11-08 23:58:46  1.325589e+18
# 166324  2020-11-08 23:58:51  1.325589e+18
# 166325  2020-11-08 23:58:56  1.325589e+18
# 166326  2020-11-08 23:59:05  1.325589e+18
# 166327  2020-11-08 23:59:21  1.325589e+18
#
#                                                     tweet  likes  \
# 0       trump student use hear year ten year hear chin...    2.0
# 1             tie tie trump rally iowa http co jjaluumh5d    4.0
# 2       clady62 minute long time ago omarosa never rep...    2.0
# 3       deeviousdenise realdonaldtrump nypost wont man...    0.0
# 4       single effective remedy eradicate another roun...    0.0
# ...                                                   ...    ...
# 166323  donaldjtrumpjr trump intimately familiar disgu...    0.0
# 166324  know decency trump gop know like child die bil...    3.0
# 166325  lionz den present white obama ready live faceb...    1.0
# 166326          trump patriot maga2020 http co 2a8fnm86ux    0.0
# 166327  lying cheating b losertrump camp protest break...    0.0
#
#         retweet_count               source       user_id  \
# 0                 1.0      Twitter Web App  8.436472e+06
# 1                 3.0   Twitter for iPhone  4.741380e+07
# 2                 0.0  Twitter for Android  1.138416e+09
# 3                 0.0   Twitter for iPhone  9.007611e+17
# 4                 0.0      Twitter Web App  5.404769e+08
# ...               ...                  ...           ...
# 166323            0.0     Twitter for iPad  1.237758e+18
# 166324            0.0      Twitter Web App  4.835231e+07
# 166325            0.0  Twitter for Android  9.868225e+17
# 166326            0.0  Twitter for Android  1.296581e+18
# 166327            0.0      Twitter Web App  2.842344e+07
#
#                                          user_name user_screen_name  \
# 0                                           snarke           snarke
# 1                            Rana Abtar - رنا أبتر        Ranaabtar
# 2                                     Farris Flagg      FarrisFlagg
# 3       Stacey Gulledge 🇺🇸 Patriot ♥️ KAG 🙏 👮‍♀️♥️      sm_gulledge
# 4                                           Jamieo         jamieo33
# ...                                            ...              ...
# 166323                                   U N Known          pirkka2
# 166324      Linda "I Voted for Biden" Kenney Baden      KenneyBaden
# 166325                              IUIC Minnesota    IUICMinnesota
# 166326                           🍿🍷••HellWorld••🍷🍿  HellWor09724785
# 166327              The Honorable Terri Lee Watson        dancertav
#
#                                          user_description  ...        lat  \
# 0       Will mock for food! Freelance writer, blogger,...  ...  45.520247
# 1       Washington Correspondent, Lebanese-American ,c...  ...  38.894992
# 2       #BidenHarris2020 #JoeBiden2020 #KamalaHarrisFo...  ...  33.782519
# 3       Patriot, Wife, “Shaken not Stirred” Mom of two...  ...  40.225357
# 4       Don't know what I am. Can lean left and right,...  ...  40.969989
# ...                                                   ...  ...        ...
# 166323  Truth will save the world - not tRump. 🌎 VOTE ...  ...  40.075738
# 166324  TrialLawyer https://t.co/1C0kKESSUC, Played by...  ...  40.712728
# 166325                                                NaN  ...  45.989659
# 166326                                                NaN  ...  34.233137
# 166327  I'm green, lean and a dancing machine. I draw,...  ...  37.167713
#
#               long        city                   country      continent  \
# 0      -122.674195    Portland  United States of America  North America
# 1       -77.036558  Washington  United States of America  North America
# 2      -117.228648         NaN  United States of America  North America
# 3       -82.688140         NaN  United States of America  North America
# 4       -77.727883         NaN  United States of America  North America
# ...            ...         ...                       ...            ...
# 166323  -74.404162         NaN  United States of America  North America
# 166324  -74.006015    New York  United States of America  North America
# 166325  -94.611329         NaN  United States of America  North America
# 166326 -102.410749         NaN  United States of America  North America
# 166327  -94.846426         NaN  United States of America  North America
#
#                        state state_code                   collected_at  \
# 0                     Oregon         OR  2020-10-21 00:00:00.746433060
# 1       District of Columbia         DC  2020-10-21 00:00:01.492866121
# 2                 California         CA  2020-10-21 00:00:01.866082651
# 3                       Ohio         OH  2020-10-21 00:00:02.612515712
# 4               Pennsylvania         PA  2020-10-21 00:00:02.985732243
# ...                      ...        ...                            ...
# 166323            New Jersey         NJ     2020-11-09 17:47:55.744839
# 166324              New York         NY     2020-11-09 17:47:55.833725
# 166325             Minnesota         MN     2020-11-09 17:47:55.847439
# 166326                 Texas         TX     2020-11-09 17:47:55.939901
# 166327                Kansas         KS     2020-11-09 17:47:56.062661
#
#        language VADER Polarity
# 0       ENGLISH       positive
# 1       ENGLISH       negative
# 2       ENGLISH       negative
# 3       ENGLISH       positive
# 4       ENGLISH       positive
# ...         ...            ...
# 166323  ENGLISH       negative
# 166324  ENGLISH       negative
# 166325  ENGLISH       positive
# 166326  ENGLISH       negative
# 166327  ENGLISH       negative
#
# [166328 rows x 23 columns]

# %% [markdown]
# ## Biden

# %%
Biden_VADER_polarity_test = [analyze_sentiment_vader_lexicon(review, threshold=0.1) for review in df_biden_eng_us.tweet]
Biden_VADER_polarity_test_df = pd.DataFrame(Biden_VADER_polarity_test, columns = ['VADER Polarity','VADER Score'])
Biden_VADER_polarity_test_df
pd.DataFrame({"count":Biden_VADER_polarity_test_df['VADER Polarity'].value_counts(),"precentage":Biden_VADER_polarity_test_df['VADER Polarity'].value_counts(normalize=True)})
# Out:
#           count  precentage
# negative  79529    0.574769
# positive  58838    0.425231

# %%
df_biden_eng_us_polarity = pd.merge(df_biden_eng_us,Biden_VADER_polarity_test_df['VADER Polarity'],left_index=True, right_index=True)
df_biden_eng_us_polarity
# Out:
#                  created_at      tweet_id  \
# 0       2020-10-15 00:00:20  1.316529e+18
# 1       2020-10-15 00:00:22  1.316529e+18
# 2       2020-10-15 00:00:25  1.316529e+18
# 3       2020-10-15 00:00:57  1.316529e+18
# 4       2020-10-15 00:01:23  1.316530e+18
# ...                     ...           ...
# 138362  2020-11-08 23:58:09  1.325588e+18
# 138363  2020-11-08 23:58:10  1.325588e+18
# 138364  2020-11-08 23:58:24  1.325589e+18
# 138365  2020-11-08 23:58:48  1.325589e+18
# 138366  2020-11-08 23:58:56  1.325589e+18
#
#                                                     tweet  likes  \
# 0       islandgirlprv bradbeauregardj meidastouch bide...    0.0
# 1       censorship hunterbiden biden bidenemails biden...    1.0
# 2       nypost censorship censored twitter manipulate ...    0.0
# 3       fbi allegedly obtain hunter biden computer dat...    0.0
# 4       comment democrat understand ruthless china htt...    0.0
# ...                                                   ...    ...
# 138362  election 2020elections trump biden http co cvk...    0.0
# 138363  gop gopleader senatemajldr lindseygrahamsc tak...    0.0
# 138364  flotus im excite flotus whose vagina havent tw...    0.0
# 138365         man need help usa biden http co f5dj8syt80    0.0
# 138366  lionz den present white obama ready live faceb...    1.0
#
#         retweet_count               source       user_id  \
# 0                 0.0      Twitter Web App  3.494182e+09
# 1                 0.0      Twitter Web App  1.032807e+18
# 2                 0.0   Twitter for iPhone  1.994033e+07
# 3                 0.0  Twitter for Android  9.607387e+17
# 4                 0.0      Twitter Web App  1.016593e+08
# ...               ...                  ...           ...
# 138362            0.0   Twitter for iPhone  9.538012e+17
# 138363            0.0  Twitter for Android  2.975783e+09
# 138364            0.0   Twitter for iPhone  5.545625e+07
# 138365            0.0  Twitter for Android  1.248047e+18
# 138366            0.0  Twitter for Android  9.868225e+17
#
#                                                 user_name user_screen_name  \
# 0                                              Flag Waver      Flag_Wavers
# 1                                          the Gold State    theegoldstate
# 2       Change Illinois | Biden will increase taxes by...   changeillinois
# 3                                               RLCompton   NewfoundStudio
# 4                                             John Ubaldi    ubaldireports
# ...                                                   ...              ...
# 138362                                    NY Gay and MAGA        NYMike912
# 138363                                      OnCapeCodTime  CapeCodBluesArt
# 138364                                 Caroline Billinson       cbillinson
# 138365                                               Dr J    DrJoeMcCarthy
# 138366                                     IUIC Minnesota    IUICMinnesota
#
#                                          user_description  ...        lat  \
# 0                                                     NaN  ...  46.304036
# 1       A Silicon Valley #independent #News #Media #St...  ...  36.701463
# 2       Illinois, home of Lincoln and Reagan, used to ...  ...  41.875562
# 3       "There are things known and there are things u...  ...  37.572603
# 4       Just Facts... No Fiction on domestic and globa...  ...  27.947760
# ...                                                   ...  ...        ...
# 138362  Gay proud. not a liberal. I was always a Democ...  ...  40.712728
# 138363  Indigenous American w/Scottish, Irish, German ...  ...  41.798807
# 138364    my love language is dismantling the patriarchy.  ...  38.894992
# 138365  Human. Free Thinker. Met Mandela. Personal. Fa...  ...  43.519630
# 138366                                                NaN  ...  45.989659
#
#               long        city                   country      continent  \
# 0      -109.171431         NaN  United States of America  North America
# 1      -118.755997         NaN  United States of America  North America
# 2       -87.624421     Chicago  United States of America  North America
# 3       -85.155141         NaN  United States of America  North America
# 4       -82.458444       Tampa  United States of America  North America
# ...            ...         ...                       ...            ...
# 138362  -74.006015    New York  United States of America  North America
# 138363  -69.996014         NaN  United States of America  North America
# 138364  -77.036558  Washington  United States of America  North America
# 138365 -114.315320         NaN  United States of America  North America
# 138366  -94.611329         NaN  United States of America  North America
#
#                        state state_code                   collected_at  \
# 0                    Montana         MT  2020-10-21 00:00:01.035654566
# 1                 California         CA  2020-10-21 00:00:02.071309132
# 2                   Illinois         IL  2020-10-21 00:00:03.106963698
# 3                   Kentucky         KY  2020-10-21 00:00:05.696100113
# 4                    Florida         FL  2020-10-21 00:00:08.803063811
# ...                      ...        ...                            ...
# 138362              New York         NY     2020-11-09 18:32:45.608982
# 138363         Massachusetts         MA     2020-11-09 18:32:45.973973
# 138364  District of Columbia         DC     2020-11-09 18:32:45.841439
# 138365                 Idaho         ID     2020-11-09 18:32:45.641087
# 138366             Minnesota         MN     2020-11-09 18:32:45.794545
#
#        language VADER Polarity
# 0       ENGLISH       negative
# 1       ENGLISH       negative
# 2       ENGLISH       negative
# 3       ENGLISH       negative
# 4       ENGLISH       negative
# ...         ...            ...
# 138362  ENGLISH       negative
# 138363  ENGLISH       negative
# 138364  ENGLISH       positive
# 138365  ENGLISH       positive
# 138366  ENGLISH       positive
#
# [138367 rows x 23 columns]

# %% [markdown]
# #Sentiment by States

# %% [markdown]
# ## Trump

# %%
df_trump_state = df_trump_eng_us_polarity[['state','VADER Polarity']].groupby(['state']).apply(lambda x:x['VADER Polarity'].value_counts(normalize=True))
df_trump_state
# Out:
# state
# Alabama        negative    0.577640
#                positive    0.422360
# Alaska         negative    0.542763
#                positive    0.457237
# Arizona        negative    0.600457
#                              ...
# West Virginia  positive    0.391635
# Wisconsin      negative    0.659012
#                positive    0.340988
# Wyoming        negative    0.622568
#                positive    0.377432
# Name: VADER Polarity, Length: 105, dtype: float64

# %% [markdown]
# ## Biden

# %%
df_biden_state = df_biden_eng_us_polarity[['state','VADER Polarity']].groupby(['state']).apply(lambda x:x['VADER Polarity'].value_counts(normalize=True))
df_biden_state
# Out:
# state
# Alabama        negative    0.558897
#                positive    0.441103
# Alaska         negative    0.592593
#                positive    0.407407
# Arizona        negative    0.578512
#                              ...
# West Virginia  positive    0.391026
# Wisconsin      negative    0.571240
#                positive    0.428760
# Wyoming        negative    0.601770
#                positive    0.398230
# Name: VADER Polarity, Length: 106, dtype: float64

# %% [markdown]
# # Sentiment By Topics

# %% [markdown]
# ## Trump

# %%
lda_trump_weights=lda_trump.transform(trump)

# %%
trump_by_topic=df_trump_eng_us
lda_trump_weights_df=pd.DataFrame(lda_trump_weights) ##Convert array of topic weights into a dataframe
lda_trump_weights_df.head()
dominant_topic = np.argmax(lda_trump_weights_df.values, axis=1)
lda_trump_weights_df['dominant_topic'] = dominant_topic ##Add dominant as a new column
lda_trump_weights_df.head()
trump_by_topic=pd.concat([trump_by_topic, lda_trump_weights_df], axis=1) ##Concat two dataframe
trump_by_topic.head() ##probability of each topic has been assigned to each tweet and a dominant topic is chosen
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:02  1.316529e+18
# 1  2020-10-15 00:00:08  1.316529e+18
# 2  2020-10-15 00:00:17  1.316529e+18
# 3  2020-10-15 00:00:18  1.316529e+18
# 4  2020-10-15 00:00:20  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  trump student use hear year ten year hear chin...    2.0            1.0
# 1        tie tie trump rally iowa http co jjaluumh5d    4.0            3.0
# 2  clady62 minute long time ago omarosa never rep...    2.0            0.0
# 3  deeviousdenise realdonaldtrump nypost wont man...    0.0            0.0
# 4  single effective remedy eradicate another roun...    0.0            0.0
#
#                 source       user_id  \
# 0      Twitter Web App  8.436472e+06
# 1   Twitter for iPhone  4.741380e+07
# 2  Twitter for Android  1.138416e+09
# 3   Twitter for iPhone  9.007611e+17
# 4      Twitter Web App  5.404769e+08
#
#                                     user_name user_screen_name  \
# 0                                      snarke           snarke
# 1                       Rana Abtar - رنا أبتر        Ranaabtar
# 2                                Farris Flagg      FarrisFlagg
# 3  Stacey Gulledge 🇺🇸 Patriot ♥️ KAG 🙏 👮‍♀️♥️      sm_gulledge
# 4                                      Jamieo         jamieo33
#
#                                     user_description  ...         1         2  \
# 0  Will mock for food! Freelance writer, blogger,...  ...  0.199622  0.213811
# 1  Washington Correspondent, Lebanese-American ,c...  ...  0.055044  0.054314
# 2  #BidenHarris2020 #JoeBiden2020 #KamalaHarrisFo...  ...  0.098209  0.123463
# 3  Patriot, Wife, “Shaken not Stirred” Mom of two...  ...  0.171466  0.064630
# 4  Don't know what I am. Can lean left and right,...  ...  0.047866  0.093292
#
#           3         4         5         6         7         8         9  \
# 0  0.110279  0.034179  0.033747  0.074031  0.034645  0.144276  0.074933
# 1  0.054431  0.182420  0.237402  0.056226  0.056546  0.054873  0.057077
# 2  0.038097  0.038406  0.037944  0.083086  0.038903  0.238485  0.264221
# 3  0.117673  0.067476  0.031351  0.068288  0.082520  0.209754  0.152540
# 4  0.143268  0.056864  0.240296  0.055571  0.045431  0.094431  0.098867
#
#   dominant_topic
# 0              2
# 1              5
# 2              9
# 3              8
# 4              5
#
# [5 rows x 33 columns]

# %%
VADER_polarity_test = [analyze_sentiment_vader_lexicon(tweet, threshold=0.1) for tweet in trump_by_topic.tweet]
VADER_polarity_test_df = pd.DataFrame(VADER_polarity_test, columns = ['VADER Polarity','VADER Score'])
trump_by_topic=pd.concat([trump_by_topic, VADER_polarity_test_df], axis=1)
trump_by_topic.head()
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:02  1.316529e+18
# 1  2020-10-15 00:00:08  1.316529e+18
# 2  2020-10-15 00:00:17  1.316529e+18
# 3  2020-10-15 00:00:18  1.316529e+18
# 4  2020-10-15 00:00:20  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  trump student use hear year ten year hear chin...    2.0            1.0
# 1        tie tie trump rally iowa http co jjaluumh5d    4.0            3.0
# 2  clady62 minute long time ago omarosa never rep...    2.0            0.0
# 3  deeviousdenise realdonaldtrump nypost wont man...    0.0            0.0
# 4  single effective remedy eradicate another roun...    0.0            0.0
#
#                 source       user_id  \
# 0      Twitter Web App  8.436472e+06
# 1   Twitter for iPhone  4.741380e+07
# 2  Twitter for Android  1.138416e+09
# 3   Twitter for iPhone  9.007611e+17
# 4      Twitter Web App  5.404769e+08
#
#                                     user_name user_screen_name  \
# 0                                      snarke           snarke
# 1                       Rana Abtar - رنا أبتر        Ranaabtar
# 2                                Farris Flagg      FarrisFlagg
# 3  Stacey Gulledge 🇺🇸 Patriot ♥️ KAG 🙏 👮‍♀️♥️      sm_gulledge
# 4                                      Jamieo         jamieo33
#
#                                     user_description  ...         3         4  \
# 0  Will mock for food! Freelance writer, blogger,...  ...  0.110279  0.034179
# 1  Washington Correspondent, Lebanese-American ,c...  ...  0.054431  0.182420
# 2  #BidenHarris2020 #JoeBiden2020 #KamalaHarrisFo...  ...  0.038097  0.038406
# 3  Patriot, Wife, “Shaken not Stirred” Mom of two...  ...  0.117673  0.067476
# 4  Don't know what I am. Can lean left and right,...  ...  0.143268  0.056864
#
#           5         6         7         8         9 dominant_topic  \
# 0  0.033747  0.074031  0.034645  0.144276  0.074933              2
# 1  0.237402  0.056226  0.056546  0.054873  0.057077              5
# 2  0.037944  0.083086  0.038903  0.238485  0.264221              9
# 3  0.031351  0.068288  0.082520  0.209754  0.152540              8
# 4  0.240296  0.055571  0.045431  0.094431  0.098867              5
#
#   VADER Polarity VADER Score
# 0       positive      0.3612
# 1       negative      0.0000
# 2       negative     -0.4767
# 3       positive      0.2732
# 4       positive      0.4767
#
# [5 rows x 35 columns]

# %%
grouped=trump_by_topic.groupby("dominant_topic")
result = grouped.apply(lambda x: x['VADER Polarity'].value_counts(normalize=True))
print(result) ##Result of VADER sentiment analysis on trump tweets grouped by each of the topic
# Out:
# VADER Polarity  negative  positive
# dominant_topic
# 0               0.692155  0.307845
# 1               0.610124  0.389876
# 2               0.602238  0.397762
# 3               0.657921  0.342079
# 4               0.590526  0.409474
# 5               0.739008  0.260992
# 6               0.546771  0.453229
# 7               0.635976  0.364024
# 8               0.695245  0.304755
# 9               0.651227  0.348773

# %% [markdown]
# ## Biden

# %%
lda_biden_weights=lda_biden.transform(biden)

# %%
biden_by_topic=df_biden_eng_us
lda_biden_weights_df=pd.DataFrame(lda_biden_weights) ##Convert array of topic weights into a dataframe
lda_biden_weights_df.head()
dominant_topic2 = np.argmax(lda_biden_weights_df.values, axis=1)
lda_biden_weights_df['dominant_topic'] = dominant_topic2 ##Add dominant as a new column
lda_biden_weights_df.head()
biden_by_topic=pd.concat([biden_by_topic, lda_biden_weights_df], axis=1) ##Concat two dataframe
biden_by_topic.head() ##probability of each topic has been assigned to each tweet and a dominant topic is chosen
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:20  1.316529e+18
# 1  2020-10-15 00:00:22  1.316529e+18
# 2  2020-10-15 00:00:25  1.316529e+18
# 3  2020-10-15 00:00:57  1.316529e+18
# 4  2020-10-15 00:01:23  1.316530e+18
#
#                                                tweet  likes  retweet_count  \
# 0  islandgirlprv bradbeauregardj meidastouch bide...    0.0            0.0
# 1  censorship hunterbiden biden bidenemails biden...    1.0            0.0
# 2  nypost censorship censored twitter manipulate ...    0.0            0.0
# 3  fbi allegedly obtain hunter biden computer dat...    0.0            0.0
# 4  comment democrat understand ruthless china htt...    0.0            0.0
#
#                 source       user_id  \
# 0      Twitter Web App  3.494182e+09
# 1      Twitter Web App  1.032807e+18
# 2   Twitter for iPhone  1.994033e+07
# 3  Twitter for Android  9.607387e+17
# 4      Twitter Web App  1.016593e+08
#
#                                            user_name user_screen_name  \
# 0                                         Flag Waver      Flag_Wavers
# 1                                     the Gold State    theegoldstate
# 2  Change Illinois | Biden will increase taxes by...   changeillinois
# 3                                          RLCompton   NewfoundStudio
# 4                                        John Ubaldi    ubaldireports
#
#                                     user_description  ...         1         2  \
# 0                                                NaN  ...  0.064775  0.061374
# 1  A Silicon Valley #independent #News #Media #St...  ...  0.060544  0.133866
# 2  Illinois, home of Lincoln and Reagan, used to ...  ...  0.057952  0.028835
# 3  "There are things known and there are things u...  ...  0.089438  0.356947
# 4  Just Facts... No Fiction on domestic and globa...  ...  0.127987  0.039581
#
#           3         4         5         6         7         8         9  \
# 0  0.188237  0.122523  0.068203  0.168768  0.097626  0.055953  0.106040
# 1  0.108659  0.273761  0.058779  0.102988  0.107320  0.052540  0.051521
# 2  0.028125  0.433661  0.121217  0.079897  0.038854  0.092049  0.060034
# 3  0.057126  0.081374  0.135983  0.116713  0.048532  0.038558  0.039320
# 4  0.131648  0.115156  0.130520  0.238598  0.032519  0.029151  0.117518
#
#   dominant_topic
# 0              3
# 1              4
# 2              4
# 3              2
# 4              6
#
# [5 rows x 33 columns]

# %%
VADER_polarity_test = [analyze_sentiment_vader_lexicon(tweet, threshold=0.1) for tweet in biden_by_topic.tweet]
VADER_polarity_test_df = pd.DataFrame(VADER_polarity_test, columns = ['VADER Polarity','VADER Score'])
biden_by_topic=pd.concat([biden_by_topic, VADER_polarity_test_df], axis=1)
biden_by_topic.head()
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:20  1.316529e+18
# 1  2020-10-15 00:00:22  1.316529e+18
# 2  2020-10-15 00:00:25  1.316529e+18
# 3  2020-10-15 00:00:57  1.316529e+18
# 4  2020-10-15 00:01:23  1.316530e+18
#
#                                                tweet  likes  retweet_count  \
# 0  islandgirlprv bradbeauregardj meidastouch bide...    0.0            0.0
# 1  censorship hunterbiden biden bidenemails biden...    1.0            0.0
# 2  nypost censorship censored twitter manipulate ...    0.0            0.0
# 3  fbi allegedly obtain hunter biden computer dat...    0.0            0.0
# 4  comment democrat understand ruthless china htt...    0.0            0.0
#
#                 source       user_id  \
# 0      Twitter Web App  3.494182e+09
# 1      Twitter Web App  1.032807e+18
# 2   Twitter for iPhone  1.994033e+07
# 3  Twitter for Android  9.607387e+17
# 4      Twitter Web App  1.016593e+08
#
#                                            user_name user_screen_name  \
# 0                                         Flag Waver      Flag_Wavers
# 1                                     the Gold State    theegoldstate
# 2  Change Illinois | Biden will increase taxes by...   changeillinois
# 3                                          RLCompton   NewfoundStudio
# 4                                        John Ubaldi    ubaldireports
#
#                                     user_description  ...         3         4  \
# 0                                                NaN  ...  0.188237  0.122523
# 1  A Silicon Valley #independent #News #Media #St...  ...  0.108659  0.273761
# 2  Illinois, home of Lincoln and Reagan, used to ...  ...  0.028125  0.433661
# 3  "There are things known and there are things u...  ...  0.057126  0.081374
# 4  Just Facts... No Fiction on domestic and globa...  ...  0.131648  0.115156
#
#           5         6         7         8         9 dominant_topic  \
# 0  0.068203  0.168768  0.097626  0.055953  0.106040              3
# 1  0.058779  0.102988  0.107320  0.052540  0.051521              4
# 2  0.121217  0.079897  0.038854  0.092049  0.060034              4
# 3  0.135983  0.116713  0.048532  0.038558  0.039320              2
# 4  0.130520  0.238598  0.032519  0.029151  0.117518              6
#
#   VADER Polarity VADER Score
# 0       negative      0.0000
# 1       negative      0.0000
# 2       negative     -0.1027
# 3       negative      0.0000
# 4       negative      0.0000
#
# [5 rows x 35 columns]

# %%
grouped2=biden_by_topic.groupby("dominant_topic")
result2 = grouped2.apply(lambda x: x['VADER Polarity'].value_counts(normalize=True))
print(result2) ##Result of VADER sentiment analysis on biden tweets grouped by each of the topic
# Out:
# dominant_topic
# 0               positive    0.617560
#                 negative    0.382440
# 1               negative    0.623912
#                 positive    0.376088
# 2               negative    0.651131
#                 positive    0.348869
# 3               negative    0.675412
#                 positive    0.324588
# 4               negative    0.648943
#                 positive    0.351057
# 5               negative    0.631809
#                 positive    0.368191
# 6               negative    0.685034
#                 positive    0.314966
# 7               positive    0.557612
#                 negative    0.442388
# 8               positive    0.527825
#                 negative    0.472175
# 9               negative    0.572921
#                 positive    0.427079
# Name: VADER Polarity, dtype: float64
